# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2 
import numpy
import matplotlib.pyplot as plt
from ssim import calcular_ssim
from mse import calculate_mse
from MSSIM import calculate_mssim


imagem1 ='reference_images/I01.BMP'
imagem2 ='distorted_images/i01_01_1.bmp'


img1 = cv2.imread(imagem1, cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread(imagem2, cv2.IMREAD_GRAYSCALE)


resultado= calculate_mssim(imagem1, imagem2)
resut = calculate_mse(img2, img1)
print (resultado)
print (resut)

# %%
img1.max()
# Out:
# 225

# %%
plt.subplot(1,2,1)
plt.imshow(img1, cmap='gray')

plt.subplot(1,2,2)
plt.imshow(img2, cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(imagem1)
plt.show()

# %%
import matplotlib.pyplot as plt
image_cvt = cv2.cvtColor(imagem1, cv2.COLOR_BGR2RGB)
plt.imshow(image_cvt)
plt.show()
